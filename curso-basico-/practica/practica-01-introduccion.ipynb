# %% [markdown]
# # Módulo 1 – Primeros Pasos en Python con Jupyter Notebook
#
# ¡Bienvenido a esta guía práctica! Aquí aprenderás los fundamentos más básicos de Python para principiantes absolutos de forma progresiva y paso a paso, usando Jupyter Notebook en VS Code. Cada ejercicio está diseñado para que construyas el código tú mismo en celdas del notebook, ejerciendo tu lógica poco a poco. Asegúrate de tener VS Code con la extensión Jupyter instalada y un kernel de Python activo.
#
# - Cómo usar esta guía como principiante:
#
# - Lee el objetivo: Entiende qué quieres lograr.
#
# - Revisa los datos: Usa estos valores exactos en tu código.
#
# - Sigue los pasos lógicos: Cada ejercicio tiene pasos numerados para que escribas el código celda por celda. ¡Prueba primero sin mirar la solución! Ejecuta con Ctrl+Enter.
#
# - Verifica requisitos: Asegúrate de cumplirlos.
#
# - Ejecuta y compara: Corre la celda y compara con la salida esperada.
#
# - Solución: Mírala solo si te atascas, para aprender del ejemplo.
#
# ---

# %% [markdown]
# ## Ejercicio 1: Verificar Instalación
# **(Dificultad: Baja | Competencia: Confirmación de Entorno Jupyter y Python)**
#
# ### Objetivo
# Confirmar que Python y Jupyter Notebook están correctamente configurados en VS Code, imprimiendo un mensaje de éxito.
#
# ### Datos que se usarán
# - Ninguno (código fijo)
#
# ### Pasos Lógicos para Construir el Código (¡Escribe línea por línea!)
# 1. **Crea una nueva celda**: En tu Jupyter Notebook (o uno nuevo), agrega una celda de código.
# 2. **Escribe el print**: Usa `print("Python instalado correctamente")` con comentario `# Verificación básica`.
# 3. **Ejecuta la celda**: Presiona Ctrl+Enter y verifica que no haya errores.
# 4. **Imprime para verificar**: Muestra el mensaje en la salida de la celda.
#
# ### Requisitos Técnicos
# - Función `print` simple.
# - Ejecución sin errores en Jupyter.
# - Salida visible en la celda.
#
# ### 🔍 Salida Esperada
# ```
# Python instalado correctamente
# ```
#
# <details>
# <summary>Haz clic para ver la solución</summary>
#
# ```python
# # Verificación básica
# print("Python instalado correctamente")
# ```
# </details>
#
# ### 🔍 Salida Esperada
# ```
# Python instalado correctamente
# ```
#
# **¡Ejercicio completado!** Entorno validado; si ves el mensaje, Jupyter y Python funcionan.
#
# ---

# %% [markdown]
# ## Ejercicio 2: Hola Mundo Personalizado
# **(Dificultad: Baja | Competencia: Salida de Texto Personalizado con Print)**
#
# ### Objetivo
# Practicar la salida de texto con `print` y personalizar un saludo con tu nombre.
#
# ### Datos que se usarán
# - Ninguno (reemplaza con tu nombre)
#
# ### Pasos Lógicos para Construir el Código
# 1. **Crea una nueva celda**: En tu Jupyter Notebook, agrega una celda de código.
# 2. **Escribe saludo genérico**: Usa `print("¡Hola, Mundo!")` con comentario `# Saludo inicial`.
# 3. **Ejecuta la celda**: Presiona Ctrl+Enter y observa la salida.
# 4. **Crea segunda celda**: Agrega otra celda y modifica: `print("¡Hola, [Tu Nombre]!")` (reemplaza [Tu Nombre] con tu nombre real, ej. "Ana").
# 5. **Ejecuta la segunda celda**: Verifica la salida personalizada.
# 6. **Imprime para verificar**: Muestra ambos mensajes en sus celdas.
#
# ### Requisitos Técnicos
# - `print` con string literal.
# - Personalización manual del texto.
# - Ejecución en celdas separadas.
#
# ### 🔍 Salida Esperada
# ```
# ¡Hola, Mundo!
# ¡Hola, Ana!
# ```
#
# <details>
# <summary>Haz clic para ver la solución</summary>
#
# ```python
# # Celda 1: Saludo inicial
# print("¡Hola, Mundo!")
#
# # Celda 2: Saludo personalizado (reemplaza "Ana" con tu nombre)
# print("¡Hola, Ana!")
# ```
# </details>
#
# **¡Bien!** Print básico; prueba agregar tu nombre real y reejecutar la segunda celda.
#
# ---

# %% [markdown]
# ## Ejercicio 3: Sintaxis con Comentario
# **(Dificultad: Baja | Competencia: Uso de Comentarios en Código)**
#
# ### Objetivo
# Comprender el uso de comentarios en Python y su efecto en el código, imprimiendo un mensaje mientras el comentario es ignorado.
#
# ### Datos que se usarán
# - Ninguno (código fijo)
#
# ### Pasos Lógicos para Construir el Código
# 1. **Crea una nueva celda**: En tu Jupyter Notebook, agrega una celda de código.
# 2. **Escribe con comentario**: Usa `# Mi primer comentario en una línea` seguido de `print("Sintaxis básica")`.
# 3. **Ejecuta la celda**: Presiona Ctrl+Enter.
# 4. **Observa el efecto**: Verifica que solo se muestre la salida del print y el comentario sea ignorado.
# 5. **Imprime para verificar**: Muestra el mensaje en la salida de la celda.
#
# ### Requisitos Técnicos
# - Comentario con `#`.
# - `print` simple.
# - Ejecución donde el comentario no afecta la salida.
#
# ### 🔍 Salida Esperada
# ```
# Sintaxis básica
# ```
#
# <details>
# <summary>Haz clic para ver la solución</summary>
#
# ```python
# # Mi primer comentario en una línea
# print("Sintaxis básica")
# ```
# </details>
#
# **¡Progreso!** Comentarios ignorados; prueba agregar otro comentario como `# Esto no se ejecuta` y reejecutar.
#
# ---

# %% [markdown]
# ## Ejercicio 4: Proyecto Final - Script de Bienvenida
# **(Dificultad: Baja | Competencia: Ejecución Secuencial en Múltiples Celdas)**
#
# ### Objetivo
# Combinar múltiples celdas para crear un script simple de bienvenida y observar la ejecución secuencial.
#
# ### Datos que se usarán
# - Ninguno (código fijo en celdas)
#
# ### Pasos Lógicos para Construir el Código
# 1. **Crea un nuevo Notebook**: En VS Code, crea un nuevo Jupyter Notebook.
# 2. **Agrega Celda 1**: Escribe `print("¡Hola, Mundo!")` con comentario `# Bienvenida inicial`.
# 3. **Agrega Celda 2**: Escribe `print("Primer paso completado")` con comentario `# Paso siguiente`.
# 4. **Agrega Celda 3**: Escribe `# Fin del script` (solo comentario).
# 5. **Ejecuta secuencialmente**: Presiona Ctrl+Enter en cada celda o usa "Ejecutar todo".
# 6. **Imprime para verificar**: Muestra las salidas en orden.
#
# ### Requisitos Técnicos
# - Múltiples celdas con `print` y comentario.
# - Ejecución secuencial sin errores.
# - Salida combinada de las celdas ejecutables.
#
# ### 🔍 Salida Esperada
# ```
# ¡Hola, Mundo!
# Primer paso completado
# ```
#
# <details>
# <summary>Haz clic para ver la solución</summary>
#
# ```python
# # Celda 1: Bienvenida inicial
# print("¡Hola, Mundo!")
#
# # Celda 2: Paso siguiente
# print("Primer paso completado")
#
# # Celda 3: Fin del script
# # Fin del script
# ```
# </details>
#
# **¡Felicidades!** Has completado los primeros pasos. Prueba ejecutar "todo" el notebook para ver el flujo secuencial.
